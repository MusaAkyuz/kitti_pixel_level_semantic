# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from utils.definitions import *
from utils.augment import *

# %% [markdown]
# Resmin boyutu ve görüntüsü aşağıdaki şekildedir.
# Birçok kamera genellikle bu boyutta bir video çekmez.
# Resmi biraz olsun şekillendirmek gerekebilir.

# %%
img = cv2.imread('./data_semantics/training/image_2/000000_10.png')
plt.title(img.shape)
plt.imshow(img)

# %%
mask = cv2.imread('./data_semantics/training/semantic_rgb/000000_10.png')
plt.title(mask.shape)
plt.imshow(mask)

# %%
result = crop_mask(mask, ROAD)
plt.title(result.shape)
plt.imshow(result)

# %% [markdown]
# Resmi 256x256 olarak şekillendirdiğimizde nasıl bir sonuç ortaya çıkacağına bakalım.

# %%
img = resize_image(img, (256, 256))
plt.title(img.shape)
plt.imshow(img)

# %%
mask = resize_image(mask, (256, 256))
plt.title(mask.shape)
plt.imshow(mask)

# %%
result = crop_mask(mask, ROAD)
plt.title(result.shape)
plt.imshow(result)
